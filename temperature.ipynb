# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from scipy.stats import skew, kurtosis
import os
import random
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy.signal import find_peaks
import pandas as pd
from scipy.fftpack import fft, fftfreq
from scipy.signal import peak_widths, peak_prominences
from scipy.io import loadmat
import seaborn as sns
from scipy.signal import spectrogram

# %%
avt = loadmat("C:\\Users\\amroa\\Documents\\thesis\\environmental\\z24_all_envdata")

# %%
avt
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Feb 04 18:22:43 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'flstruc': array(['01C14', '01C15', '01C16', ..., '44F11', '44F12', '44F13'],
#        dtype='<U5'),
#  'x': array([[[-3.121200e-04, -3.121200e-04,  0.000000e+00, ...,
#            0.000000e+00,  0.000000e+00, -3.121200e-04],
#          [ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,
#           -6.242400e-04, -3.121200e-04, -6.242400e-04],
#          [ 5.181210e-01,  5.206180e-01,  5.221786e-01, ...,
#            5.936544e-01,  5.967756e-01,  6.155028e-01],
#          ...,
#          [-2.442000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.443000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02]],
#
#         [[ 0.000000e+00, -3.121200e-04, -3.121200e-04, ...,
#            0.000000e+00,  0.000000e+00,  0.000000e+00],
#          [ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,
#           -3.121200e-04, -3.121200e-04, -6.242400e-04],
#          [ 5.156241e-01,  5.181210e-01,  5.224907e-01, ...,
#            5.930302e-01,  5.961514e-01,  6.158150e-01],
#          ...,
#          [-2.442000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.442000e+02, -2.443000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02]],
#
#         [[ 0.000000e+00,  0.000000e+00, -3.121200e-04, ...,
#            0.000000e+00, -3.121200e-04,  0.000000e+00],
#          [ 3.121200e-04, -3.121200e-04,  3.121200e-04, ...,
#           -6.242400e-04, -6.242400e-04, -3.121200e-04],
#          [ 5.171847e-01,  5.196817e-01,  5.212422e-01, ...,
#            5.933423e-01,  5.964634e-01,  6.155028e-01],
#          ...,
#          [-2.442000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.442000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.442000e+02, -2.443000e+02, ...,
#           -2.443000e+02, -2.442000e+02, -2.442000e+02]],
#
#         ...,
#
#         [[ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,
#            0.000000e+00,  0.000000e+00, -3.121200e-04],
#          [ 0.000000e+00, -3.121200e-04,  0.000000e+00, ...,
#           -6.242400e-04, -3.121200e-04, -6.242400e-04],
#          [ 5.193696e-01,  5.149999e-01,  5.262362e-01, ...,
#            5.886604e-01,  5.964634e-01,  6.117574e-01],
#          ...,
#          [-2.443000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.443000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.443000e+02]],
#
#         [[-3.121200e-04,  0.000000e+00, -3.121200e-04, ...,
#            0.000000e+00,  0.000000e+00,  0.000000e+00],
#          [ 0.000000e+00,  0.000000e+00, -3.121200e-04, ...,
#           -6.242400e-04, -3.121200e-04,  0.000000e+00],
#          [ 5.190574e-01,  5.168726e-01,  5.277968e-01, ...,
#            5.889726e-01,  5.952149e-01,  6.120695e-01],
#          ...,
#          [-2.442000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02]],
#
#         [[ 0.000000e+00,  0.000000e+00,  0.000000e+00, ...,
#           -3.121200e-04, -3.121200e-04,  0.000000e+00],
#          [-3.121200e-04, -3.121200e-04,  0.000000e+00, ...,
#            0.000000e+00,  0.000000e+00, -3.121200e-04],
#          [ 5.193696e-01,  5.162483e-01,  5.262362e-01, ...,
#            5.877241e-01,  5.952149e-01,  6.111332e-01],
#          ...,
#          [-2.442000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.443000e+02, -2.443000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02],
#          [-2.443000e+02, -2.442000e+02, -2.442000e+02, ...,
#           -2.442000e+02, -2.442000e+02, -2.442000e+02]]])}

# %%
avt['x'].shape
# Out:
# (20, 53, 5652)
